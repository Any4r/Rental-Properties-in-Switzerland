# %% [markdown]
# # Web Scraping

# %% [markdown]
# ## Web Request

# %%
import requests

"""
   Constants
   -------
   
   TIMEOUT: str
       Connection timeout in seconds.
   

   Methods
   -------
   get_data(url: str, path: str)
       Performs GET request to given url+path. 
       In case of unstable connection this method will finish whole application execution.
       Returns HTML as str.
   """

TIMEOUT = 10


def get_data(url, path):
    full_url = "{}{}".format(url, path)
    try:
        response = requests.get(full_url, timeout=TIMEOUT)
        if response.status_code != 200:
            raise requests.ConnectionError
        return response.text
    except:
        print("->\t[ERROR]: Could not get data from {}. Please, try again.".format(full_url))
        exit(1)

# %% [markdown]
# ## HTML Parsing

# %%
from bs4 import BeautifulSoup, SoupStrainer
import re


"""
   Methods
   -------
   filter_data(document: str)
       Parse target tags in provided HTML, get text data and parse it to retrieve needed values.
       Returns list of lists of dictionaries with data.
       
   parse_heading(heading: string)
       Parse values from <h3> tag text using Regular Expressions.
       Returns dictionary with target values.
       
   parse_address(address: string)
       Parse values from <address> tag text using Regular Expressions.
       Returns dictionary with target values.
       
   print_missing_property_log(src_string: str, missing: str)
       Prints log to output. Used if target property is missing in analyzed string.
       
   """


def filter_data(document):
    result = []
    # Get only <article> tags.
    only_articles = SoupStrainer('article')
    soup = BeautifulSoup(document, 'html.parser', parse_only=only_articles)
    articles = soup.findAll('article')
    for a in articles:
        # Create BeautifulSoup instance to analyze article.
        article = BeautifulSoup(str(a), 'html.parser')
        # Create BeautifulSoup instance to analyze h3 heading.
        heading = BeautifulSoup(str(article.find('h3')), 'html.parser').text
        heading_content = parse_heading(heading)

        # Create BeautifulSoup instance to analyze address.
        address = BeautifulSoup(str(article.find('address')), 'html.parser').text
        address_content = parse_address(address)

        # Merge result article data into one dictionary.
        article_data = {**heading_content, **address_content}
        result.append(article_data)
    return result


def parse_heading(heading):
    result = {
        "num_rooms": None,
        "m2": None,
        "price": None
    }

    try:
        result["num_rooms"] = re.findall(r'^(\d+,\d|\d+)', heading)[0].replace(',', '.')
    except:
        print_missing_property_log(heading, "rooms number")
        pass
    try:
        result["m2"] = re.findall(r'(\d+)(?:\sm)', heading)[0]
    except:
        print_missing_property_log(heading, "square")
        pass
    try:
        result["price"] = re.findall(r'(\d+)(?:\.)', heading)[0]
    except:
        print_missing_property_log(heading, "price")
        pass
    return result


def parse_address(address):
    result = {
        "street": None,
        "zip_code": None,
        "city": None,
        "canton_code": None
    }

    try:
        result["street"] = re.findall(r'^(\D+\s*)+(?:\s\d+)|^(\D+\.)', address)[0][0]
    except:
        print_missing_property_log(address, "street name")
        pass
    try:
        result["zip_code"] = re.findall(r'\d{4}', address)[0]
    except:
        print_missing_property_log(address, "ZIP code")
        pass
    try:
        result["city"] = re.findall(r'(?:\d{4}\s)(\D{3,})+(?:,)', address)[0]
    except:
        print_missing_property_log(address, "city name")
        pass
    try:
        result["canton_code"] = re.findall(r'\D{2}$', address)[0]
    except:
        print_missing_property_log(address, "canton name")
        pass
    return result


def print_missing_property_log(src_string, missing):
    print("->\t[WARNING]: problem at string: '{}'. No {} provided!".format(src_string, missing))

# %% [markdown]
# ## Dataframe and CSV

# %%
import csv
import pandas as pd

"""
   Methods
   -------
   store_results(results: list of lists of dictionaries, filename: str)
       Store data to file.
       
   """

def store_results(results, filename):
    # Flatten list of lists.
    flat=[]
    for i in scraped_data:
        for j in i:
            flat.append(j)
    
    # Define columns of dataframe.
    cols_list = ["num_rooms", "m2", "price", "zip_code", 
             "canton_code", "street", "city"]

     # Append dictionary into dataframe.
    df = pd.DataFrame(columns=cols_list)
    df = df.append(flat, ignore_index = True)
    
    # Remove NA's and store objects in the target type
    df.dropna(axis=0, how ="any", inplace=True)
    df[['m2', 'price', 'zip_code']] = df[['m2', 'price', 'zip_code']].astype(int)
    df['num_rooms'] = df['num_rooms'].astype(float)

    # Saving dataframe as csv.
    df.to_csv(filename,encoding = "latin1", index = False)

# %% [markdown]
# ## Scraping

# %%
"""
   Constants
   ----------
   DATA_URL : str
       Target URL without request path.
   PAGES_NUMBER : 42
       Number of pages to scrape.
   EXCEL_FILE_NAME : str
       Name of the target .xls file.

   Methods
   -------
   print_processing_log(page_number : int, url_path : str)
       Prints info about currently processing page.
       
   print_post_processing_log()
       Prints post processing log.
       
   """

DATA_URL = 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl'
PAGES_NUMBER = 42
CSV_FILE_NAME = "immoscout_src.csv"


def print_processing_log(page_number, url_path):
    print(
        "[INFO]: Processing page {} of {} at '{}'".format(page_number, PAGES_NUMBER, "{}{}".format(DATA_URL, url_path)))


def print_post_processing_log():
    print("\n[INFO] All pages parsed! Saving results to {}.".format(CSV_FILE_NAME))


if __name__ == '__main__':

    scraped_data = []
    current_page = 1
    while current_page <= PAGES_NUMBER:
        # Define URL path to next page.
        path = "" if current_page < 2 else "?pn={}".format(current_page)
        print_processing_log(current_page, path)
        # Get HTML from website and parse it.
        filtered_data = filter_data(get_data(DATA_URL, path))
        scraped_data = [*scraped_data, filtered_data]
        current_page += 1

    print_post_processing_log()
    # Write data to file.
    store_results(scraped_data, CSV_FILE_NAME)
# Out:
# [INFO]: Processing page 1 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl'
# ->	[WARNING]: problem at string: '4 Zimmer, 87 mÂ², Preis auf Anfrage'. No price provided!
# ->	[WARNING]: problem at string: '4,5 Zimmer, 116 mÂ², Preis auf Anfrage'. No price provided!
# ->	[WARNING]: problem at string: '4,5 Zimmer, 89 mÂ², Preis auf Anfrage'. No price provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, 86 mÂ², Preis auf Anfrage'. No price provided!
# ->	[WARNING]: problem at string: '3 Zimmer, 68 mÂ², Preis auf Anfrage'. No price provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, 82 mÂ², Preis auf Anfrage'. No price provided!
# [INFO]: Processing page 2 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=2'
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1590.â'. No square provided!
# [INFO]: Processing page 3 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=3'
# [INFO]: Processing page 4 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=4'
# ->	[WARNING]: problem at string: '1815 Clarens, VD'. No street name provided!
# ->	[WARNING]: problem at string: '3 Zimmer, CHF 1890.â'. No square provided!
# [INFO]: Processing page 5 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=5'
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 2483.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1840.â'. No square provided!
# [INFO]: Processing page 6 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=6'
# [INFO]: Processing page 7 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=7'
# [INFO]: Processing page 8 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=8'
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1910.â'. No square provided!
# [INFO]: Processing page 9 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=9'
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1880.â'. No square provided!
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1680.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1180.â'. No square provided!
# ->	[WARNING]: problem at string: '4,5 Zimmer, 114 mÂ², Preis auf Anfrage'. No price provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1490.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1655.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1800.â'. No square provided!
# [INFO]: Processing page 10 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=10'
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1330.â'. No square provided!
# ->	[WARNING]: problem at string: '2,5 Zimmer, CHF 1690.â'. No square provided!
# [INFO]: Processing page 11 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=11'
# ->	[WARNING]: problem at string: '5,5 Zimmer, CHF 1750.â'. No square provided!
# [INFO]: Processing page 12 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=12'
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1085.â'. No square provided!
# ->	[WARNING]: problem at string: '2 Zimmer, CHF 1000.â'. No square provided!
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1095.â'. No square provided!
# [INFO]: Processing page 13 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=13'
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1680.â'. No square provided!
# ->	[WARNING]: problem at string: 'Chemin du Chalet Pra Roman 4C, 1000 Lausanne 26, VD'. No city name provided!
# ->	[WARNING]: problem at string: '4 Zimmer, CHF 1180.â'. No square provided!
# ->	[WARNING]: problem at string: '2,5 Zimmer, CHF 1150.â'. No square provided!
# ->	[WARNING]: problem at string: '2 Zimmer, CHF 980.â'. No square provided!
# ->	[WARNING]: problem at string: '1 Zimmer, CHF 780.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1200.â'. No square provided!
# [INFO]: Processing page 14 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=14'
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 2200.â'. No square provided!
# ->	[WARNING]: problem at string: '6 Zimmer, CHF 4480.â'. No square provided!
# ->	[WARNING]: problem at string: '3005 Bern, BE'. No street name provided!
# ->	[WARNING]: problem at string: '2,5 Zimmer, CHF 950.â'. No square provided!
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1430.â'. No square provided!
# [INFO]: Processing page 15 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=15'
# ->	[WARNING]: problem at string: '3 Zimmer, CHF 745.â'. No square provided!
# ->	[WARNING]: problem at string: '3 Zimmer, CHF 1890.â'. No square provided!
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1100.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1000.â'. No square provided!
# [INFO]: Processing page 16 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=16'
# [INFO]: Processing page 17 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=17'
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1600.â'. No square provided!
# ->	[WARNING]: problem at string: '4 Zimmer, CHF 1350.â'. No square provided!
# [INFO]: Processing page 18 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=18'
# ->	[WARNING]: problem at string: '1 Zimmer, CHF 1070.â'. No square provided!
# ->	[WARNING]: problem at string: '4 Zimmer, CHF 1530.â'. No square provided!
# ->	[WARNING]: problem at string: '1820 Montreux, VD'. No street name provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1190.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1300.â'. No square provided!
# ->	[WARNING]: problem at string: '3 Zimmer, CHF 1250.â'. No square provided!
# [INFO]: Processing page 19 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=19'
# ->	[WARNING]: problem at string: '2,5 Zimmer, CHF 1080.â'. No square provided!
# ->	[WARNING]: problem at string: '45, rue de la Dixence, 1950 Sion, VS'. No street name provided!
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1600.â'. No square provided!
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1930.â'. No square provided!
# [INFO]: Processing page 20 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=20'
# ->	[WARNING]: problem at string: '2,5 Zimmer, CHF 920.â'. No square provided!
# ->	[WARNING]: problem at string: '3 Zimmer, CHF 1850.â'. No square provided!
# ->	[WARNING]: problem at string: '5,5 Zimmer, CHF 2150.â'. No square provided!
# ->	[WARNING]: problem at string: '1789 Lugnorre, FR'. No street name provided!
# [INFO]: Processing page 21 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=21'
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1395.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1450.â'. No square provided!
# [INFO]: Processing page 22 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=22'
# ->	[WARNING]: problem at string: 'CHF 2250.â'. No rooms number provided!
# ->	[WARNING]: problem at string: 'CHF 2250.â'. No square provided!
# ->	[WARNING]: problem at string: '6900 Lugano, TI'. No street name provided!
# [INFO]: Processing page 23 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=23'
# ->	[WARNING]: problem at string: '5113 Holderbank AG, AG'. No street name provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1150.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, 70 mÂ², Preis auf Anfrage'. No price provided!
# ->	[WARNING]: problem at string: '1,5 Zimmer, CHF 550.â'. No square provided!
# [INFO]: Processing page 24 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=24'
# ->	[WARNING]: problem at string: '2,5 Zimmer, CHF 1050.â'. No square provided!
# ->	[WARNING]: problem at string: '22 HelvÃ©tie, 2300 La Chaux-de-Fonds, NE'. No street name provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1890.â'. No square provided!
# ->	[WARNING]: problem at string: '3 Zimmer, CHF 1292.â'. No square provided!
# ->	[WARNING]: problem at string: '4 Zimmer, CHF 1760.â'. No square provided!
# [INFO]: Processing page 25 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=25'
# ->	[WARNING]: problem at string: '2 Zimmer, CHF 995.â'. No square provided!
# ->	[WARNING]: problem at string: '3 Zimmer, CHF 1050.â'. No square provided!
# ->	[WARNING]: problem at string: '5,5 Zimmer, Preis auf Anfrage'. No square provided!
# ->	[WARNING]: problem at string: '5,5 Zimmer, Preis auf Anfrage'. No price provided!
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 2290.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1690.â'. No square provided!
# [INFO]: Processing page 26 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=26'
# ->	[WARNING]: problem at string: 'Preis auf Anfrage'. No rooms number provided!
# ->	[WARNING]: problem at string: 'Preis auf Anfrage'. No square provided!
# ->	[WARNING]: problem at string: 'Preis auf Anfrage'. No price provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, 90 mÂ², Preis auf Anfrage'. No price provided!
# ->	[WARNING]: problem at string: '3422 AlchenflÃ¼h, BE'. No street name provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1750.â'. No square provided!
# ->	[WARNING]: problem at string: 'Preis auf Anfrage'. No rooms number provided!
# ->	[WARNING]: problem at string: 'Preis auf Anfrage'. No square provided!
# ->	[WARNING]: problem at string: 'Preis auf Anfrage'. No price provided!
# [INFO]: Processing page 27 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=27'
# ->	[WARNING]: problem at string: '1 Zimmer, CHF 510.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, 112 mÂ², Preis auf Anfrage'. No price provided!
# [INFO]: Processing page 28 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=28'
# ->	[WARNING]: problem at string: '8104 Weiningen ZH, ZH'. No street name provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 790.â'. No square provided!
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1200.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 990.â'. No square provided!
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1290.â'. No square provided!
# ->	[WARNING]: problem at string: '2,5 Zimmer, CHF 1130.â'. No square provided!
# ->	[WARNING]: problem at string: '2,5 Zimmer, CHF 950.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1590.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, 120 mÂ², Preis auf Anfrage'. No price provided!
# [INFO]: Processing page 29 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=29'
# ->	[WARNING]: problem at string: '2,5 Zimmer, CHF 1590.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1050.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1640.â'. No square provided!
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1630.â'. No square provided!
# [INFO]: Processing page 30 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=30'
# ->	[WARNING]: problem at string: '5 Zimmer, CHF 1850.â'. No square provided!
# ->	[WARNING]: problem at string: '3 Zimmer, CHF 1150.â'. No square provided!
# [INFO]: Processing page 31 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=31'
# ->	[WARNING]: problem at string: '1,5 Zimmer, CHF 850.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1200.â'. No square provided!
# ->	[WARNING]: problem at string: '3 Zimmer, CHF 1020.â'. No square provided!
# ->	[WARNING]: problem at string: '3 Zimmer, CHF 1075.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1280.â'. No square provided!
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1600.â'. No square provided!
# ->	[WARNING]: problem at string: '2 Zimmer, CHF 1050.â'. No square provided!
# [INFO]: Processing page 32 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=32'
# ->	[WARNING]: problem at string: '2 Zimmer, CHF 1050.â'. No square provided!
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1100.â'. No square provided!
# ->	[WARNING]: problem at string: '3 Zimmer, CHF 1480.â'. No square provided!
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1800.â'. No square provided!
# ->	[WARNING]: problem at string: '4 Zimmer, CHF 1340.â'. No square provided!
# [INFO]: Processing page 33 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=33'
# ->	[WARNING]: problem at string: '2,5 Zimmer, CHF 1135.â'. No square provided!
# ->	[WARNING]: problem at string: '1,5 Zimmer, CHF 790.â'. No square provided!
# ->	[WARNING]: problem at string: '2,5 Zimmer, CHF 1350.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1450.â'. No square provided!
# [INFO]: Processing page 34 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=34'
# ->	[WARNING]: problem at string: '1,5 Zimmer, CHF 925.â'. No square provided!
# ->	[WARNING]: problem at string: '3 Zimmer, CHF 1050.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 950.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1450.â'. No square provided!
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1990.â'. No square provided!
# [INFO]: Processing page 35 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=35'
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1720.â'. No square provided!
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1530.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1790.â'. No square provided!
# [INFO]: Processing page 36 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=36'
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1400.â'. No square provided!
# ->	[WARNING]: problem at string: '3 Zimmer, CHF 1150.â'. No square provided!
# ->	[WARNING]: problem at string: '4 Zimmer, CHF 1280.â'. No square provided!
# [INFO]: Processing page 37 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=37'
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1650.â'. No square provided!
# ->	[WARNING]: problem at string: '1214 Vernier, GE'. No street name provided!
# ->	[WARNING]: problem at string: '2,5 Zimmer, CHF 1165.â'. No square provided!
# ->	[WARNING]: problem at string: '2,5 Zimmer, CHF 1490.â'. No square provided!
# ->	[WARNING]: problem at string: '4 Zimmer, CHF 1680.â'. No square provided!
# [INFO]: Processing page 38 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=38'
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 2130.â'. No square provided!
# ->	[WARNING]: problem at string: '2 Zimmer, CHF 1220.â'. No square provided!
# ->	[WARNING]: problem at string: '1 Zimmer, CHF 805.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1695.â'. No square provided!
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1525.â'. No square provided!
# ->	[WARNING]: problem at string: '3 Zimmer, CHF 990.â'. No square provided!
# ->	[WARNING]: problem at string: '2 Zimmer, CHF 960.â'. No square provided!
# [INFO]: Processing page 39 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=39'
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1340.â'. No square provided!
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1890.â'. No square provided!
# ->	[WARNING]: problem at string: '1170 Aubonne, VD'. No street name provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, 88 mÂ², Preis auf Anfrage'. No price provided!
# ->	[WARNING]: problem at string: '4 Zimmer, CHF 1220.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1290.â'. No square provided!
# ->	[WARNING]: problem at string: '2,5 Zimmer, CHF 1090.â'. No square provided!
# ->	[WARNING]: problem at string: '2,5 Zimmer, CHF 980.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1590.â'. No square provided!
# ->	[WARNING]: problem at string: '2,5 Zimmer, CHF 1210.â'. No square provided!
# ->	[WARNING]: problem at string: '4 Zimmer, CHF 1660.â'. No square provided!
# [INFO]: Processing page 40 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=40'
# ->	[WARNING]: problem at string: '1 Zimmer, CHF 720.â'. No square provided!
# ->	[WARNING]: problem at string: '4,5 Zimmer, CHF 1490.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1290.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1250.â'. No square provided!
# [INFO]: Processing page 41 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=41'
# ->	[WARNING]: problem at string: '2 Zimmer, CHF 990.â'. No square provided!
# ->	[WARNING]: problem at string: '1730 Ecuvillens, FR'. No street name provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1430.â'. No square provided!
# ->	[WARNING]: problem at string: '4 Zimmer, CHF 1990.â'. No square provided!
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 3800.â'. No square provided!
# ->	[WARNING]: problem at string: '2,5 Zimmer, CHF 1350.â'. No square provided!
# [INFO]: Processing page 42 of 42 at 'https://www.immoscout24.ch/de/wohnung/mieten/land-schweiz-fl?pn=42'
# ->	[WARNING]: problem at string: '3,5 Zimmer, CHF 1190.â'. No square provided!
# ->	[WARNING]: problem at string: '4 Zimmer, CHF 1690.â'. No square provided!
#
# [INFO] All pages parsed! Saving results to immoscout_src.csv.

# %% [markdown]
# # Data Cleaning

# %%
# Read dirsource csv file.
df1 = pd.read_csv("immoscout_src.csv")

# Read dirty excel file.
df2 = pd.read_excel("immoscout_src_dirty.xlsx")

# Remove all rows with NA's.
df2.dropna(axis=0, how ="any", inplace=True)

# Replace wrongly displayed characters with correct ones.
df2 = df2.replace('Ã¼','ü', regex=True)
df2 = df2.replace('Ã¨','è', regex=True)
df2 = df2.replace('Ã©','é', regex=True)
df2 = df2.replace('Ã¤','ä', regex=True)
df2 = df2.replace('Ã¤','â', regex=True)
df2 = df2.replace('Ã¶','ö', regex=True)

# Remove all rows where datatype in column "zip_code" is not numeric
df2 = df2[pd.to_numeric(df2['zip_code'], errors='coerce').notnull()]

# Remove all duplicate rows
df2.drop_duplicates()

# Store objects in the target type
df2[['m2', 'price', 'zip_code']] = df2[['m2', 'price', 'zip_code']].astype(int)
df2['num_rooms'] = df2['num_rooms'].astype(float)

# Store cleaned dataframe as excel and csv.
df2.to_excel("immoscout_stage.xlsx", index = False)
df2.to_csv("immoscout_stage.csv", index = False)

# %% [markdown]
# # Loading

# %%
import mysql.connector
from sqlalchemy import create_engine

# Defining our connection variables
username = "alina"
password = "Salami1993"
ipaddress = "localhost"
dbname = "CIP" 

# A long string that contains the necessary Postgres login information
engine = create_engine("mysql+mysqlconnector://alina:Salami1993@localhost/CIP")

df1.to_sql(name = "immoscout_src", con=engine, if_exists = "replace", index=False) 
df2.to_sql(name = "immoscout_stage", con=engine, if_exists = "replace", index=False)
print("MariaDB has been updated.")
# Out:
# MariaDB has been updated.
